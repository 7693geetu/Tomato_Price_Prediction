# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.svm import LinearSVR, SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
import warnings
warnings.filterwarnings(action='ignore')

# %%
data = pd.read_csv("C:/Users/archa/Downloads/dataset_tomato_AK1111.csv")

# %%
data
# Out:
#                 Unnamed: 0 Unnamed: 1 Unnamed: 2           Unnamed: 3  \
# 0                      NaN        NaN        NaN                  NaN
# 1   Vegitable Date(Tomato)     Season      Month  Temprature(deg.Cel)
# 2                10/1/2023          3         10                   32
# 3                10/2/2023          3         10                   31
# 4                10/3/2023          3         10                   33
# 5                10/4/2023          3         10                   33
# 6                10/5/2023          3         10                   33
# 7                10/6/2023          3         10                   34
# 8                10/7/2023          3         10                   33
# 9                10/8/2023          3         10                   34
# 10               10/9/2023          3         10                   34
# 11              10/10/2023          3         10                   34
# ...

# %%
index_to_delete = 0
data = data.drop(index_to_delete)

# %%
data
# Out:
#                 Unnamed: 0 Unnamed: 1 Unnamed: 2           Unnamed: 3  \
# 1   Vegitable Date(Tomato)     Season      Month  Temprature(deg.Cel)
# 2                10/1/2023          3         10                   32
# 3                10/2/2023          3         10                   31
# 4                10/3/2023          3         10                   33
# 5                10/4/2023          3         10                   33
# 6                10/5/2023          3         10                   33
# 7                10/6/2023          3         10                   34
# 8                10/7/2023          3         10                   33
# 9                10/8/2023          3         10                   34
# 10               10/9/2023          3         10                   34
# 11              10/10/2023          3         10                   34
# 12              10/11/2023          3         10                   34
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 1 to 52
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  52 non-null     object
#  1   Unnamed: 1  52 non-null     object
#  2   Unnamed: 2  52 non-null     object
#  3   Unnamed: 3  52 non-null     object
#  4   Unnamed: 4  52 non-null     object
#  5   Unnamed: 5  52 non-null     object
#  6   Unnamed: 6  52 non-null     object
# dtypes: object(7)
# memory usage: 3.0+ KB

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6'],
#       dtype='object')

# %%
x=data[['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
       'Unnamed: 5']]
y=['Unnamed: 6']

# %%
from sklearn.model_selection import train_test_split

# %%
np.random.seed(0)
x=np.random.rand(51,6)
y=np.random.rand(51,1)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
lm.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
# Model Evaluation
y = lm.predict(x_test)

# Mean Squared Error and R-squared for model evaluation
mse = mean_squared_error(y_test, y)
r2 = r2_score(y_test, y)

print("Mean Squared Error:", mse)
print("R-squared:", r2)
# Out:
# Mean Squared Error: 0.08558383622278415
# R-squared: -0.1880555209449808

# %%
import matplotlib.pyplot as plt

# %%
# Predictions and Visualization
# To visualize the predictions against actual prices, we'll use a scatter plot
plt.scatter(y_test, y)
plt.xlabel("Actual Prices")
plt.ylabel("Predicted Prices")
plt.title("Actual Prices vs. Predicted Prices")
plt.show()

# We can also create a residual plot to check the model's performance
residuals = y_test - y
plt.scatter(y_test, residuals)
plt.axhline(y=0, color='red', linestyle='--')
plt.xlabel("Actual Prices")
plt.ylabel("Residuals")
plt.title("Residual Plot")
plt.show()

# Lastly, let's use the trained model to make predictions on new data and visualize the results
new_data = [['25/11/2023','3','11','32','0','1']]
predicted_prices = lm.predict(new_data)

print("Predicted Prices:", predicted_prices[0])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 20
#      18 # Lastly, let's use the trained model to make predictions on new data and visualize the results
#      19 new_data = [['25/11/2023','3','11','32','0','1']]
# ---> 20 predicted_prices = lm.predict(new_data)
#      22 print("Predicted Prices:", predicted_prices[0])
#
# File ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py:386, in LinearModel.predict(self, X)
#     372 def predict(self, X):
#     373     """
#     374     Predict using the linear model.
#     375
#    (...)
#     384         Returns predicted values.
#     385     """
# --> 386     return self._decision_function(X)
#
# File ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py:369, in LinearModel._decision_function(self, X)
#     366 def _decision_function(self, X):
#     367     check_is_fitted(self)
# ...
